# %%
import pandas as pd
data = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# adding new column in existing dataset
data["New_Col"]="pvp"
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#duplicate column 
data["Name_new"]=data["Name"]
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#new column with addition of two existing column
data["age_Pclass"]= data["Age"] + data["Pclass"]
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Delete the column ; axis 0 -> Row, axis 1 -> column
data.drop('New_Col', axis=1)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked New_Col  \
# 0      0         A/5 21171   7.2500   NaN        S     pvp
# 1      0          PC 17599  71.2833   C85        C     pvp
# 2      0  STON/O2. 3101282   7.9250   NaN        S     pvp
# 3      0            113803  53.1000  C123        S     pvp
# ...

# %%
# with drop function column got deleted temoprary, with inplace=True value it will delecte the calue parmanently.
data.drop('New_Col', axis=1, inplace=True)
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  \
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
#
# ...

# %%
# Row operations 
data.drop(0)
#Here no need to give axis value because by default axis value is zero
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# 5                                     Moran, Mr. James    male   NaN      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# In above dataset 0th row is not available but is not re-assigened to data variable so chnages are temporary.
# And if we want it to delete is permanant then use the inplace=True option with drop
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data = data.drop(0)
data
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# 5                                     Moran, Mr. James    male   NaN      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# above we have applied assignment operation so row got deleted permanant.

# %%
#Fetch the Row number 1
data.iloc[0]
# Out:
# PassengerId                                                    2
# Survived                                                       1
# Pclass                                                         1
# Name           Cumings, Mrs. John Bradley (Florence Briggs Th...
# Sex                                                       female
# Age                                                         38.0
# SibSp                                                          1
# Parch                                                          0
# Ticket                                                  PC 17599
# Fare                                                     71.2833
# Cabin                                                        C85
# Embarked                                                       C
# Name_new       Cumings, Mrs. John Bradley (Florence Briggs Th...
# age_Pclass                                                  39.0
# Name: 1, dtype: object

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
#
#    Parch            Ticket     Fare Cabin Embarked  \
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# 5      0            330877   8.4583   NaN        Q
#
# ...

# %%
data.loc[1]
# Out:
# PassengerId                                                    2
# Survived                                                       1
# Pclass                                                         1
# Name           Cumings, Mrs. John Bradley (Florence Briggs Th...
# Sex                                                       female
# Age                                                         38.0
# SibSp                                                          1
# Parch                                                          0
# Ticket                                                  PC 17599
# Fare                                                     71.2833
# Cabin                                                        C85
# Embarked                                                       C
# Name_new       Cumings, Mrs. John Bradley (Florence Briggs Th...
# age_Pclass                                                  39.0
# Name: 1, dtype: object

# %%
### Difference between iloc and loc
#iloc >> it will go with default(in-built) indexing starts with 0
#loc >> it will get the index from the dataset

# %%
#Fetch the data from index 2 to 5
data.loc[2:5]
# Out:
#    PassengerId  Survived  Pclass  \
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 2                        Heikkinen, Miss. Laina  female  26.0      0      0
# 3  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 4                      Allen, Mr. William Henry    male  35.0      0      0
# 5                              Moran, Mr. James    male   NaN      0      0
#
#              Ticket     Fare Cabin Embarked  \
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500   NaN        S
# 5            330877   8.4583   NaN        Q
#
#                                        Name_new  age_Pclass
# 2                        Heikkinen, Miss. Laina        29.0
# 3  Futrelle, Mrs. Jacques Heath (Lily May Peel)        36.0
# ...

# %%
#Fetch the data from index 101 to 106 and cloumn name is Surviewed and Pclass
data.loc[101:106]
# Out:
#      PassengerId  Survived  Pclass                              Name     Sex  \
# 101          102         0       3  Petroff, Mr. Pastcho ("Pentcho")    male
# 102          103         0       1         White, Mr. Richard Frasar    male
# 103          104         0       3        Johansson, Mr. Gustaf Joel    male
# 104          105         0       3    Gustafsson, Mr. Anders Vilhelm    male
# 105          106         0       3             Mionoff, Mr. Stoytcho    male
# 106          107         1       3  Salkjelsvik, Miss. Anna Kristine  female
#
#       Age  SibSp  Parch   Ticket     Fare Cabin Embarked  \
# 101   NaN      0      0   349215   7.8958   NaN        S
# 102  21.0      0      1    35281  77.2875   D26        S
# 103  33.0      0      0     7540   8.6542   NaN        S
# 104  37.0      2      0  3101276   7.9250   NaN        S
# 105  28.0      0      0   349207   7.8958   NaN        S
# 106  21.0      0      0   343120   7.6500   NaN        S
#
# ...

# %%
data.loc[101:106, ['Survived', 'Pclass']]
# Out:
#      Survived  Pclass
# 101         0       3
# 102         0       1
# 103         0       3
# 104         0       3
# 105         0       3
# 106         1       3

# %%
# to fetch specific data
data.loc[3:5, ['Fare', 'Cabin', 'Embarked']]
# Out:
#       Fare Cabin Embarked
# 3  53.1000  C123        S
# 4   8.0500   NaN        S
# 5   8.4583   NaN        Q

# %%
data.iloc[3:5, ['Fare', 'Cabin', 'Embarked']]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9932\150204553.py in <module>
# ----> 1 data.iloc[3:5, ['Fare', 'Cabin', 'Embarked']]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     959             if self._is_scalar_access(key):
#     960                 return self.obj._get_value(*key, takeable=self._takeable)
# --> 961             return self._getitem_tuple(key)
#     962         else:
#     963             # we by definition only have the 0th axis
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    1459     def _getitem_tuple(self, tup: tuple):
#    1460
# -> 1461         tup = self._validate_tuple_indexer(tup)
#    1462         with suppress(IndexingError):
#    1463             return self._getitem_lowerdim(tup)
#
# ...

# %%
# for iloc, we need to give numeric index for  ['Fare' 'Cabin' 'Embarked'].
data.iloc[2:5, [9, 10, 11]]
# Out:
#       Fare Cabin Embarked
# 3  53.1000  C123        S
# 4   8.0500   NaN        S
# 5   8.4583   NaN        Q

# %%
data.iloc[[2, 3, 4], [9, 10, 11]]
# Out:
#       Fare Cabin Embarked
# 3  53.1000  C123        S
# 4   8.0500   NaN        S
# 5   8.4583   NaN        Q

# %%
#  Fetch the passangerID and PClass column using iloc and loc
data.loc[: ,['PassengerId', 'Pclass']]
# Out:
#      PassengerId  Pclass
# 1              2       1
# 2              3       3
# 3              4       1
# 4              5       3
# 5              6       3
# ..           ...     ...
# 886          887       2
# 887          888       1
# 888          889       3
# 889          890       1
# 890          891       3
#
# [890 rows x 2 columns]

# %%
data.iloc[: ,[0, 2]]
# Out:
#      PassengerId  Pclass
# 1              2       1
# 2              3       3
# 3              4       1
# 4              5       3
# 5              6       3
# ..           ...     ...
# 886          887       2
# 887          888       1
# 888          889       3
# 889          890       1
# 890          891       3
#
# [890 rows x 2 columns]

# %%
data.loc[[3, 5], ['PassengerId','Survived', 'Pclass']]
# Out:
#    PassengerId  Survived  Pclass
# 3            4         1       1
# 5            6         0       3

# %%
#Fetch the all record where age is greater than 35
data[data['Age']>35]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 6              7         0       1
# 11            12         1       1
# 13            14         0       3
# 15            16         1       2
# ..           ...       ...     ...
# 865          866         1       2
# 871          872         1       1
# 873          874         0       3
# 879          880         1       1
# 885          886         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 13                         Andersson, Mr. Anders Johan    male  39.0      1
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#Fetch the all record where age is greater than 35 and passsenger class is 1
data[data['Pclass']==1]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 11            12         1       1
# 23            24         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 23                        Sloper, Mr. William Thompson    male  28.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data1 = data.iloc[1:5, [2,3,4,5,9,10]]
data1
# Out:
#    Pclass                                          Name     Sex   Age  \
# 2       3                        Heikkinen, Miss. Laina  female  26.0
# 3       1  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4       3                      Allen, Mr. William Henry    male  35.0
# 5       3                              Moran, Mr. James    male   NaN
#
#       Fare Cabin
# 2   7.9250   NaN
# 3  53.1000  C123
# 4   8.0500   NaN
# 5   8.4583   NaN

# %%
# rename the row index 
data1.set_index('Name')
# Out:
#                                               Pclass     Sex   Age     Fare  \
# Name
# Heikkinen, Miss. Laina                             3  female  26.0   7.9250
# Futrelle, Mrs. Jacques Heath (Lily May Peel)       1  female  35.0  53.1000
# Allen, Mr. William Henry                           3    male  35.0   8.0500
# Moran, Mr. James                                   3    male   NaN   8.4583
#
#                                              Cabin
# Name
# Heikkinen, Miss. Laina                         NaN
# Futrelle, Mrs. Jacques Heath (Lily May Peel)  C123
# Allen, Mr. William Henry                       NaN
# Moran, Mr. James                               NaN

# %%
# Drop all the records where we have null values
data1.dropna()
# Out:
#    Pclass                                          Name     Sex   Age  Fare  \
# 3       1  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0  53.1
#
#   Cabin
# 3  C123

# %%
# by deafutl axis=0 so it is cheking row wise
# For column wise do make axis=1
data1.dropna(axis=1)
# Out:
#    Pclass                                          Name     Sex     Fare
# 2       3                        Heikkinen, Miss. Laina  female   7.9250
# 3       1  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  53.1000
# 4       3                      Allen, Mr. William Henry    male   8.0500
# 5       3                              Moran, Mr. James    male   8.4583

# %%
data1.dropna(axis=1, thresh=1)
# Out:
#    Pclass                                          Name     Sex   Age  \
# 2       3                        Heikkinen, Miss. Laina  female  26.0
# 3       1  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4       3                      Allen, Mr. William Henry    male  35.0
# 5       3                              Moran, Mr. James    male   NaN
#
#       Fare Cabin
# 2   7.9250   NaN
# 3  53.1000  C123
# 4   8.0500   NaN
# 5   8.4583   NaN

# %%
data1.dropna(axis=1, thresh=2)
# Out:
#    Pclass                                          Name     Sex   Age     Fare
# 2       3                        Heikkinen, Miss. Laina  female  26.0   7.9250
# 3       1  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0  53.1000
# 4       3                      Allen, Mr. William Henry    male  35.0   8.0500
# 5       3                              Moran, Mr. James    male   NaN   8.4583

# %%
#thresh required non-na values ex.thresh=1 it reqired atleast 2 non-na value
data1.dropna(axis=1, thresh=4)
# Out:
#    Pclass                                          Name     Sex     Fare
# 2       3                        Heikkinen, Miss. Laina  female   7.9250
# 3       1  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  53.1000
# 4       3                      Allen, Mr. William Henry    male   8.0500
# 5       3                              Moran, Mr. James    male   8.4583

# %%
data1.dropna(axis=0, thresh=5)
# Out:
#    Pclass                                          Name     Sex   Age    Fare  \
# 2       3                        Heikkinen, Miss. Laina  female  26.0   7.925
# 3       1  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0  53.100
# 4       3                      Allen, Mr. William Henry    male  35.0   8.050
#
#   Cabin
# 2   NaN
# 3  C123
# 4   NaN

# %%
data1
# Out:
#    Pclass                                          Name     Sex   Age  \
# 2       3                        Heikkinen, Miss. Laina  female  26.0
# 3       1  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4       3                      Allen, Mr. William Henry    male  35.0
# 5       3                              Moran, Mr. James    male   NaN
#
#       Fare Cabin
# 2   7.9250   NaN
# 3  53.1000  C123
# 4   8.0500   NaN
# 5   8.4583   NaN

# %%
#Fill na value with certain value
data1.fillna('pvp')
# Out:
#    Pclass                                          Name     Sex   Age  \
# 2       3                        Heikkinen, Miss. Laina  female  26.0
# 3       1  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4       3                      Allen, Mr. William Henry    male  35.0
# 5       3                              Moran, Mr. James    male   pvp
#
#       Fare Cabin
# 2   7.9250   pvp
# 3  53.1000  C123
# 4   8.0500   pvp
# 5   8.4583   pvp

# %%
data1.fillna(data1["Age"].mean())
# Out:
#    Pclass                                          Name     Sex   Age  \
# 2       3                        Heikkinen, Miss. Laina  female  26.0
# 3       1  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4       3                      Allen, Mr. William Henry    male  35.0
# 5       3                              Moran, Mr. James    male  32.0
#
#       Fare Cabin
# 2   7.9250  32.0
# 3  53.1000  C123
# 4   8.0500  32.0
# 5   8.4583  32.0

# %%
data1['Age'].fillna(data1["Age"].mean())
# Out:
# 2    26.0
# 3    35.0
# 4    35.0
# 5    32.0
# Name: Age, dtype: float64

# %%
data.groupby('Sex').count()
# Out:
#         PassengerId  Survived  Pclass  Name  Age  SibSp  Parch  Ticket  Fare  \
# Sex
# female          314       314     314   314  261    314    314     314   314
# male            576       576     576   576  452    576    576     576   576
#
#         Cabin  Embarked  Name_new  age_Pclass
# Sex
# female     97       312       314         261
# male      107       576       576         452

# %%
data.groupby('Sex').mean()
# Out:
#         PassengerId  Survived    Pclass        Age     SibSp     Parch  \
# Sex
# female   431.028662  0.742038  2.159236  27.915709  0.694268  0.649682
# male     454.934028  0.189236  2.388889  30.745951  0.428819  0.236111
#
#              Fare  age_Pclass
# Sex
# female  44.479818   29.980843
# male    25.555619   33.080022

# %%
#Total fare paid by male and female
data.groupby('Sex').sum()['Fare']
# Out:
# Sex
# female    13966.6628
# male      14720.0365
# Name: Fare, dtype: float64

# %%
data2=data.iloc[0:4, 0:5]
data2
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                             Heikkinen, Miss. Laina  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                           Allen, Mr. William Henry    male

# %%
data1
# Out:
#    Pclass                                          Name     Sex   Age  \
# 2       3                        Heikkinen, Miss. Laina  female  26.0
# 3       1  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4       3                      Allen, Mr. William Henry    male  35.0
# 5       3                              Moran, Mr. James    male   NaN
#
#       Fare Cabin
# 2   7.9250   NaN
# 3  53.1000  C123
# 4   8.0500   NaN
# 5   8.4583   NaN

# %%
#concat two or more dataset
pd.concat([data1, data2])
# Out:
#    Pclass                                               Name     Sex   Age  \
# 2       3                             Heikkinen, Miss. Laina  female  26.0
# 3       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4       3                           Allen, Mr. William Henry    male  35.0
# 5       3                                   Moran, Mr. James    male   NaN
# 1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   NaN
# 2       3                             Heikkinen, Miss. Laina  female   NaN
# 3       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   NaN
# 4       3                           Allen, Mr. William Henry    male   NaN
#
#       Fare Cabin  PassengerId  Survived
# 2   7.9250   NaN          NaN       NaN
# 3  53.1000  C123          NaN       NaN
# 4   8.0500   NaN          NaN       NaN
# 5   8.4583   NaN          NaN       NaN
# 1      NaN   NaN          2.0       1.0
# 2      NaN   NaN          3.0       1.0
# ...

# %% [markdown]
# concat() is row wise concatination by default.

# %%
pd.concat([data1, data2],axis=1)
# Out:
#    Pclass                                          Name     Sex   Age  \
# 2     3.0                        Heikkinen, Miss. Laina  female  26.0
# 3     1.0  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4     3.0                      Allen, Mr. William Henry    male  35.0
# 5     3.0                              Moran, Mr. James    male   NaN
# 1     NaN                                           NaN     NaN   NaN
#
#       Fare Cabin  PassengerId  Survived  Pclass  \
# 2   7.9250   NaN          3.0       1.0     3.0
# 3  53.1000  C123          4.0       1.0     1.0
# 4   8.0500   NaN          5.0       0.0     3.0
# 5   8.4583   NaN          NaN       NaN     NaN
# 1      NaN   NaN          2.0       1.0     1.0
#
#                                                 Name     Sex
# 2                             Heikkinen, Miss. Laina  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                           Allen, Mr. William Henry    male
# ...

# %%
data1
# Out:
#    Pclass                                          Name     Sex   Age  \
# 2       3                        Heikkinen, Miss. Laina  female  26.0
# 3       1  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4       3                      Allen, Mr. William Henry    male  35.0
# 5       3                              Moran, Mr. James    male   NaN
#
#       Fare Cabin
# 2   7.9250   NaN
# 3  53.1000  C123
# 4   8.0500   NaN
# 5   8.4583   NaN

# %%
#devide Pclass by 3
data1['New_col']= data1['Pclass']
data1
# Out:
#    Pclass                                          Name     Sex   Age  \
# 2       3                        Heikkinen, Miss. Laina  female  26.0
# 3       1  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4       3                      Allen, Mr. William Henry    male  35.0
# 5       3                              Moran, Mr. James    male   NaN
#
#       Fare Cabin  New_col
# 2   7.9250   NaN        3
# 3  53.1000  C123        1
# 4   8.0500   NaN        3
# 5   8.4583   NaN        3

# %%
data1['New_col']= data1['Pclass'].apply(lambda x: x/3)

# %%
data1
# Out:
#    Pclass                                          Name     Sex   Age  \
# 2       3                        Heikkinen, Miss. Laina  female  26.0
# 3       1  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4       3                      Allen, Mr. William Henry    male  35.0
# 5       3                              Moran, Mr. James    male   NaN
#
#       Fare Cabin   New_col
# 2   7.9250   NaN  1.000000
# 3  53.1000  C123  0.333333
# 4   8.0500   NaN  1.000000
# 5   8.4583   NaN  1.000000

# %%
def fun1(x):
    return x/3

# %%
data1['New_col']= data1['Pclass'].apply(fun1)
data1
# Out:
#    Pclass                                          Name     Sex   Age  \
# 2       3                        Heikkinen, Miss. Laina  female  26.0
# 3       1  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4       3                      Allen, Mr. William Henry    male  35.0
# 5       3                              Moran, Mr. James    male   NaN
#
#       Fare Cabin   New_col
# 2   7.9250   NaN  1.000000
# 3  53.1000  C123  0.333333
# 4   8.0500   NaN  1.000000
# 5   8.4583   NaN  1.000000

# %%
data2
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                             Heikkinen, Miss. Laina  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                           Allen, Mr. William Henry    male

# %%
data2["New_Col"]=data2["Name"].apply(len)
data2
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  New_Col
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female       51
# 2                             Heikkinen, Miss. Laina  female       22
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female       44
# 4                           Allen, Mr. William Henry    male       24

# %%
import math
def cus1(x):
    if x < 3:
        return x
    else: 
        return math.log10(x)

# %%
data2["PassId_new"]=data2["PassengerId"].apply(cus1)

# %%
data2
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  New_Col  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female       51
# 2                             Heikkinen, Miss. Laina  female       22
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female       44
# 4                           Allen, Mr. William Henry    male       24
#
#    PassId_new
# 1    2.000000
# 2    0.477121
# 3    0.602060
# 4    0.698970

# %%
def cus2(x):
    if x == 'male':
        return 0
    else: 
        return 1

# %%
data2["Sex_new"]=data2["Sex"].apply(cus2)

# %%
data2
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  New_Col  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female       51
# 2                             Heikkinen, Miss. Laina  female       22
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female       44
# 4                           Allen, Mr. William Henry    male       24
#
#    PassId_new  Sex_new
# 1    2.000000        1
# 2    0.477121        1
# 3    0.602060        1
# 4    0.698970        0

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
#
#    Parch            Ticket     Fare Cabin Embarked  \
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# 5      0            330877   8.4583   NaN        Q
#
# ...

# %%
# 0-100 -> "A", 101-199 -> "B", 200+ -> "C"
def cus3(x):
    if x <= 100:
        return "A"
    elif x > 100 and x < 200:
        return "B"
    else:
        return "c"

# %%
data["New_Fare"]=data["Fare"].apply(cus3)

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# 5                                     Moran, Mr. James    male   NaN      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked  \
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q
#
#                                      Name_new  age_Pclass New_Fare
# ...

# %%
data[data["New_Fare"] == "B"]
# Out:
#      PassengerId  Survived  Pclass  \
# 31            32         1       1
# 195          196         1       1
# 215          216         1       1
# 268          269         1       1
# 269          270         1       1
# 297          298         0       1
# 305          306         1       1
# 306          307         1       1
# 307          308         1       1
# 318          319         1       1
# 319          320         1       1
# 325          326         1       1
# 332          333         0       1
# 334          335         1       1
# 337          338         1       1
# 373          374         0       1
# 390          391         1       1
# 393          394         1       1
# 435          436         1       1
# 498          499         0       1
# 505          506         0       1
# 537          538         1       1
# 544          545         0       1
# 550          551         1       1
# 581          582         1       1
# ...

# %%
data[data["New_Fare"] == "c"]
# Out:
#      PassengerId  Survived  Pclass  \
# 27            28         0       1
# 88            89         1       1
# 118          119         0       1
# 258          259         1       1
# 299          300         1       1
# 311          312         1       1
# 341          342         1       1
# 377          378         0       1
# 380          381         1       1
# 438          439         0       1
# 527          528         0       1
# 557          558         0       1
# 679          680         1       1
# 689          690         1       1
# 700          701         1       1
# 716          717         1       1
# 730          731         1       1
# 737          738         1       1
# 742          743         1       1
# 779          780         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 27                      Fortune, Mr. Charles Alexander    male  19.0      3
# ...

# %%
data["Fare"].max()
# Out:
# 512.3292
